# %% [markdown]
# <a href="https://colab.research.google.com/github/ajit211998/Ajit-Kumar/blob/main/great_learning_data_science_projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# great learning data science projects

# %%
import pandas as pd
from matplotlib import  pyplot as plt 
import seaborn as sns

# %%
fifa=pd.read_csv('players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
#
# [5 rows x 104 columns]

# %%
for col in fifa.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (6199, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# Spain                 535
# Brazil                520
# Argentina             476
# France                386
# Germany               364
#                      ...
# Azerbaijan              1
# Puerto Rico             1
# Dominican Republic      1
# New Caledonia           1
# Kazakhstan              1
# Name: nationality, Length: 128, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# Spain          535
# Brazil         520
# Argentina      476
# France         386
# Germany        364
# England        312
# Italy          303
# Portugal       201
# Colombia       173
# Netherlands    168
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# Spain        535
# Brazil       520
# Argentina    476
# France       386
# Germany      364
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['Spain', 'Brazil', 'Argentina', 'France', 'Germany'], dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color='g')
plt.show()

# %%
fifa['nationality'].value_counts()[0:5].index
# Out:
# Index(['Spain', 'Brazil', 'Argentina', 'France', 'Germany'], dtype='object')

# %%
player_salary=fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color=['r','g','b','orange','pink'])
plt.show()

# %%
fifa['nationality']=='germany'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6194    False
# 6195    False
# 6196    False
# 6197    False
# 6198    False
# Name: nationality, Length: 6199, dtype: bool

# %%
Germany=fifa[fifa['nationality']=='Germany']
Germany.head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...  ...   NaN   NaN
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...  ...  55+3  64+3
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...  ...  84+3  78+3
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 1217     200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...  ...   NaN   NaN
# 4449     158657  https://sofifa.com/player/158657/thomas-kessle...  ...   NaN   NaN
# 5107     216284  https://sofifa.com/player/216284/florian-balla...  ...  69+2  57+2
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...  ...   NaN   NaN
# 1217     200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 165      213331  https://sofifa.com/player/213331/jonathan-tah/...  ...  81+2  73+2
# 77       212190  https://sofifa.com/player/212190/niklas-sule/2...  ...  83+2  75+2
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...  ...  52+2  61+2
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...  ...  72+3  74+3
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...  ...  55+3  64+3
#
# [5 rows x 104 columns]

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 37         M. Reus    170000

# %% [markdown]
# #sorting

# %%
player_shooting=fifa[['short_name','shooting']]

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#defending

# %%
player_defending=fifa[['short_name','defending','nationality','club']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 16  G. Chiellini       90.0        Italy           Juventus
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 49    M. Hummels       89.0      Germany  Borussia Dortmund
# 35      D. Godín       89.0      Uruguay              Inter

# %%
real_madririd=fifa[fifa['club']=='Real Madrid']

# %%
real_madririd.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 46     165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
#
# [5 rows x 104 columns]

# %%
real_madririd.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...  ...  66+3  70+3
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...  ...  57+3  62+3
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...  ...  47+2  51+2
# 46      165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
#
# [5 rows x 104 columns]

# %%
real_madririd.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...  ...  84+3  79+3
# 76      201535  https://sofifa.com/player/201535/raphael-varan...  ...  83+3  77+3
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...  ...  80+3  83+3
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...  ...  79+2  78+2
#
# [5 rows x 104 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g6FJ8hUZV1pUpZU_ymq-qkmdHCUL6NcsWvpNjXmoB9K5195SLs-Glw
# Mounted at /content/drive

# %%
real_madririd['nationality'].value_counts()
# Out:
# Spain                 9
# Brazil                6
# France                3
# Belgium               2
# Uruguay               1
# Japan                 1
# Serbia                1
# Costa Rica            1
# Dominican Republic    1
# Croatia               1
# Germany               1
# Wales                 1
# Colombia              1
# Name: nationality, dtype: int64

# %%
import pandas as pd
from matplotlib import  pyplot as plt

# %%
battle=pd.read_csv('/content/battles.csv')

# %%
battle.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
battle.shape
# Out:
# (38, 25)

# %%
battle.rename(columns={'attacker_1':'primary_attacker'},inplace=True)

# %%
battle.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
battle['attacker_king'].value_counts()
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
battle['location'].value_counts()
# Out:
# Riverrun                                3
# Winterfell                              3
# Moat Cailin                             2
# Deepwood Motte                          2
# Storm's End                             2
# Torrhen's Square                        2
# Harrenhal                               2
# Darry                                   2
# Golden Tooth                            1
# Red Fork                                1
# Ruby Ford                               1
# Saltpans                                1
# Oxcross                                 1
# Seagard                                 1
# Crag                                    1
# Stony Shore                             1
# Green Fork                              1
# Mummer's Ford                           1
# Whispering Wood                         1
# Castle Black                            1
# Dragonstone                             1
# Ryamsport, Vinetown, Starfish Harbor    1
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.barplot(x='attacker_king',y='attacker_size',data=battle)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-aa524d4b6e0a> in <module>()
#       1 sns.set(rc={'figure.figsize':(13,5)})
# ----> 2 sns.barplot(x='attacker_king',y='attacker_size',data=battles)
#       3 plt.show()
#
# NameError: name 'battles' is not defined

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.barplot(x='defender_king',y='defender_size',data=battle)
plt.show()

# %%
sns.countplot(x=battle['attacker_king'],hue=battle['battle_type'])
plt.show()

# %%
death=pd.read_csv('/content/character-deaths.csv')

# %%
death.head()
# Out:
#                       Name      Allegiances  Death Year  ...  SoS  FfC  DwD
# 0           Addam Marbrand        Lannister         NaN  ...    1    1    0
# 1  Aegon Frey (Jinglebell)             None       299.0  ...    1    0    0
# 2          Aegon Targaryen  House Targaryen         NaN  ...    0    0    1
# 3            Adrack Humble    House Greyjoy       300.0  ...    0    0    1
# 4           Aemon Costayne        Lannister         NaN  ...    1    0    0
#
# [5 rows x 13 columns]

# %%
death.shape
# Out:
# (917, 13)

# %%
death['Gender'].value_counts()
# Out:
# 1    760
# 0    157
# Name: Gender, dtype: int64

# %%
death['Nobility'].value_counts()
# Out:
# 0    487
# 1    430
# Name: Nobility, dtype: int64

# %%
sns.countplot(death['Death Year'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(30,10)})
sns.countplot(death['Allegiances'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x='attacker_king',y='attacker_size',data=battle)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3f82b57e8324> in <module>()
#       1 sns.set(rc={'figure.figsize':(15,10)})
# ----> 2 sns.barplot(x='attacker_king',y='attacker_size',data=battle)
#       3 plt.show()
#
# NameError: name 'battle' is not defined

# %%
import pandas as pd

# %%
mydata=pd.read_csv("/heart.csv")

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
mydata=pd.read_csv("/heart.csv")

# %%
mydata.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 0   63    1   3     145   233    1  ...     0      2.3    0    0      1       1
# 1   37    1   2     130   250    0  ...     0      3.5    0    0      2       1
# 2   41    0   1     130   204    0  ...     0      1.4    2    0      2       1
# 3   56    1   1     120   236    0  ...     0      0.8    2    0      2       1
# 4   57    0   0     120   354    0  ...     1      0.6    2    0      2       1
#
# [5 rows x 14 columns]

# %%
mydata.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 298   57    0   0     140   241    0  ...     1      0.2    1    0      3       0
# 299   45    1   3     110   264    0  ...     0      1.2    1    0      3       0
# 300   68    1   0     144   193    1  ...     0      3.4    1    2      3       0
# 301   57    1   0     130   131    0  ...     1      1.2    1    1      3       0
# 302   57    0   1     130   236    0  ...     0      0.0    1    1      2       0
#
# [5 rows x 14 columns]

# %%
for col in mydata.columns:
  print(col)
# Out:
# age
# sex
# cp
# trtbps
# chol
# fbs
# restecg
# thalachh
# exng
# oldpeak
# slp
# caa
# thall
# output

# %%
mydata.shape
# Out:
# (303, 14)
